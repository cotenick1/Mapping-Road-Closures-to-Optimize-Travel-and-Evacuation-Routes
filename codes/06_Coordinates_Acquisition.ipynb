# %% [markdown]
# # 06. Coordinate Acquisition
# ---

# %% [markdown]
# The purpose of this notebook is to leverage the `geocoder` mapping library in order to acquire the latitude and longitude coordinates for the locations referenced in the collected and cleaned tweets.  This process is executed after we have extracted locations identified in each tweet posted by one of the NJ 511 twitter accounts in the previous notebook.

# %% [markdown]
# ---
# ## Table of Contents
# ---
#
# - [Import Resources](#Import-Resources)
# - [DataFrame Series Setup](#DataFrame-Series-Setup)
# - [Organize and Save](#Organize-and-Save)

# %% [markdown]
# ---
# ### Import Resources
# ---

# %% [markdown]
# Here we import the necessary libraries to enable geocode acquisition.  Furthermore, we read-in the cleaned `closure_location` data.

# %%
import pandas as pd
import geocoder

# %% [markdown]
# Read-in and light cleaning of csv

# %%
locs_df = pd.read_csv("../datasets/closure_locations.csv")

# Drop unncessary column
locs_df.drop(columns = "Unnamed: 0", inplace = True)

# Fill blank cells with ''
locs_df.fillna('', inplace = True)

locs_df.head()
# Out:
#     username                                              tweet  \
# 0  511nji295  Crash on I-295 southbound South of Exit 29 - U...
# 1   511njace  Construction, bridge painting on Atlantic City...
# 2   511njtpk  Roadwork on New Jersey Turnpike inner roadway ...
# 3   511nji76  Crash on I-76 eastbound at Exit 2 - I-676 (Cam...
# 4   511njtpk  Roadwork on New Jersey Turnpike inner roadway ...
#
#                  date_posted  \
# 0  2019-11-06 23:56:56+00:00
# 1  2019-11-06 23:52:57+00:00
# 2  2019-11-06 23:41:56+00:00
# 3  2019-11-06 23:41:56+00:00
# 4  2019-11-06 23:27:56+00:00
#
#                                       expanded_tweet  \
# 0  Crash on Interstate 295 southbound South of Ex...
# 1  Construction, bridge painting on Atlantic City...
# 2  Roadwork on New Jersey Turnpike inner roadway ...
# 3  Crash on Interstate 76 eastbound at Exit 2 - I...
# 4  Roadwork on New Jersey Turnpike inner roadway ...
#
#                                              highway streets  \
# 0                                     Interstate 295
# 1                           Atlantic City Expressway
# 2  New Jersey Turnpike, Interchange 6 - Pennsylva...
# 3                                      Interstate 76
# 4  New Jersey Turnpike, Interchange 14 - Intersta...
#
#                                                exits  directions locs  \
# 0                                    Exit 29 - US-30  southbound
# 1  Exit 12 - US-40 - Wrangleboro Road, Exit 12 - ...   westbound
# 2                                                     northbound
# 3                            Exit 2 - Interstate 676   eastbound
# 4                                                     Southbound
#
#             lanes                          relocs  \
# 0      right lane                        South of
# 1      right lane        between East of, West of
# 2                                            from
# 3  right shoulder
# 4       all lanes  between North of, and South of
#
#                                    town
# 0                        Haddon Heights
# 1  Hamilton Township, Hamilton Township
# 2
# 3                                Camden
# 4                                Newark

# %% [markdown]
# ---
# ### DataFrame Series Setup
# ---

# %% [markdown]
# Setting up table for acquiring coordinates

# %% [markdown]
# Creating `state` variable to add to location

# %%
state = "NJ"

# %% [markdown]
# Iterating through each identifiable location and setting up a `location_lookup` column for each non `''` cell.

# %%
# creating state variable to add to location_lookup
state = 'NJ'

# creating blank location_lookup column to fill via below for loop
locs_df['location_lookup'] = ''

# loop to populate location_lookup column
for i in list(range(locs_df.shape[0])):
    if locs_df['town'].loc[i] != '':
        locs_df['location_lookup'].loc[i] = locs_df['town'].loc[i] + ', ' + state
        
    elif locs_df['exits'].loc[i] != '':
        locs_df['location_lookup'].loc[i] = locs_df['exits'].loc[i] + ', ' + state
        
    elif locs_df['streets'].loc[i] != '':
        locs_df['location_lookup'].loc[i] = locs_df['streets'].loc[i] + ', ' + state
        
    elif locs_df['highway'].loc[i] != '':
        locs_df['location_lookup'].loc[i] = locs_df['highway'].loc[i] + ', ' + state
        
    else:
        locs_df['location_lookup'].loc[i] = state

# %%
locs_df.head()
# Out:
#     username                                              tweet  \
# 0  511nji295  Crash on I-295 southbound South of Exit 29 - U...
# 1   511njace  Construction, bridge painting on Atlantic City...
# 2   511njtpk  Roadwork on New Jersey Turnpike inner roadway ...
# 3   511nji76  Crash on I-76 eastbound at Exit 2 - I-676 (Cam...
# 4   511njtpk  Roadwork on New Jersey Turnpike inner roadway ...
#
#                  date_posted  \
# 0  2019-11-06 23:56:56+00:00
# 1  2019-11-06 23:52:57+00:00
# 2  2019-11-06 23:41:56+00:00
# 3  2019-11-06 23:41:56+00:00
# 4  2019-11-06 23:27:56+00:00
#
#                                       expanded_tweet  \
# 0  Crash on Interstate 295 southbound South of Ex...
# 1  Construction, bridge painting on Atlantic City...
# 2  Roadwork on New Jersey Turnpike inner roadway ...
# 3  Crash on Interstate 76 eastbound at Exit 2 - I...
# 4  Roadwork on New Jersey Turnpike inner roadway ...
#
#                                              highway streets  \
# 0                                     Interstate 295
# 1                           Atlantic City Expressway
# 2  New Jersey Turnpike, Interchange 6 - Pennsylva...
# 3                                      Interstate 76
# 4  New Jersey Turnpike, Interchange 14 - Intersta...
#
#                                                exits  directions locs  \
# 0                                    Exit 29 - US-30  southbound
# 1  Exit 12 - US-40 - Wrangleboro Road, Exit 12 - ...   westbound
# 2                                                     northbound
# 3                            Exit 2 - Interstate 676   eastbound
# 4                                                     Southbound
#
#             lanes                          relocs  \
# 0      right lane                        South of
# 1      right lane        between East of, West of
# 2                                            from
# 3  right shoulder
# 4       all lanes  between North of, and South of
#
#                                    town  \
# 0                        Haddon Heights
# 1  Hamilton Township, Hamilton Township
# 2
# 3                                Camden
# 4                                Newark
#
#                                      location_lookup
# 0                                 Haddon Heights, NJ
# 1           Hamilton Township, Hamilton Township, NJ
# 2  New Jersey Turnpike, Interchange 6 - Pennsylva...
# 3                                         Camden, NJ
# 4                                         Newark, NJ

# %%
# test
geocoder.arcgis(locs_df['location_lookup'][0]).latlng
# Out:
# [39.88187000000005, -75.05929999999995]

# %% [markdown]
# Acquiring coordinates - ***this will take about 30 minutes, given the amount of locations to iterate through***

# %%
locs_df['coordinates'] = [geocoder.arcgis(locs_df['location_lookup'][i]).latlng for i in list(range(locs_df.shape[0]))]

# %%
locs_df.head()
# Out:
#     username                                              tweet  \
# 0  511nji295  Crash on I-295 southbound South of Exit 29 - U...
# 1   511njace  Construction, bridge painting on Atlantic City...
# 2   511njtpk  Roadwork on New Jersey Turnpike inner roadway ...
# 3   511nji76  Crash on I-76 eastbound at Exit 2 - I-676 (Cam...
# 4   511njtpk  Roadwork on New Jersey Turnpike inner roadway ...
#
#                  date_posted  \
# 0  2019-11-06 23:56:56+00:00
# 1  2019-11-06 23:52:57+00:00
# 2  2019-11-06 23:41:56+00:00
# 3  2019-11-06 23:41:56+00:00
# 4  2019-11-06 23:27:56+00:00
#
#                                       expanded_tweet  \
# 0  Crash on Interstate 295 southbound South of Ex...
# 1  Construction, bridge painting on Atlantic City...
# 2  Roadwork on New Jersey Turnpike inner roadway ...
# 3  Crash on Interstate 76 eastbound at Exit 2 - I...
# 4  Roadwork on New Jersey Turnpike inner roadway ...
#
#                                              highway streets  \
# 0                                     Interstate 295
# 1                           Atlantic City Expressway
# 2  New Jersey Turnpike, Interchange 6 - Pennsylva...
# 3                                      Interstate 76
# 4  New Jersey Turnpike, Interchange 14 - Intersta...
#
#                                                exits  directions locs  \
# 0                                    Exit 29 - US-30  southbound
# 1  Exit 12 - US-40 - Wrangleboro Road, Exit 12 - ...   westbound
# 2                                                     northbound
# 3                            Exit 2 - Interstate 676   eastbound
# 4                                                     Southbound
#
#             lanes                          relocs  \
# 0      right lane                        South of
# 1      right lane        between East of, West of
# 2                                            from
# 3  right shoulder
# 4       all lanes  between North of, and South of
#
#                                    town  \
# 0                        Haddon Heights
# 1  Hamilton Township, Hamilton Township
# 2
# 3                                Camden
# 4                                Newark
#
#                                      location_lookup  \
# 0                                 Haddon Heights, NJ
# 1           Hamilton Township, Hamilton Township, NJ
# 2  New Jersey Turnpike, Interchange 6 - Pennsylva...
# 3                                         Camden, NJ
# 4                                         Newark, NJ
#
#                                 coordinates
# 0   [39.88187000000005, -75.05929999999995]
# 1  [40.230360000000076, -74.72385999999995]
# 2   [41.02283671772758, -78.44427748447676]
# 3  [39.945250000000044, -75.11912999999998]
# 4   [40.73197000000005, -74.17420999999996]

# %% [markdown]
# ---
# ### Organize and Save
# ---

# %% [markdown]
# We will organize the results of the geocoder into a usable dataframe and save it down as a csv for use by other notebooks.

# %% [markdown]
# Splitting latitude and longitude into seperate Series in the DataFrame

# %%
# Create latitude column
locs_df['lat'] = [coords[0] for coords in locs_df['coordinates']]

# Create longitude column
locs_df['lon'] = [coords[1] for coords in locs_df['coordinates']]

# Drop coordinates column
locs_df.drop(columns = "coordinates", inplace = True)

# %%
# Take a look at results from above seperation
locs_df.head()
# Out:
#     username                                              tweet  \
# 0  511nji295  Crash on I-295 southbound South of Exit 29 - U...
# 1   511njace  Construction, bridge painting on Atlantic City...
# 2   511njtpk  Roadwork on New Jersey Turnpike inner roadway ...
# 3   511nji76  Crash on I-76 eastbound at Exit 2 - I-676 (Cam...
# 4   511njtpk  Roadwork on New Jersey Turnpike inner roadway ...
#
#                  date_posted  \
# 0  2019-11-06 23:56:56+00:00
# 1  2019-11-06 23:52:57+00:00
# 2  2019-11-06 23:41:56+00:00
# 3  2019-11-06 23:41:56+00:00
# 4  2019-11-06 23:27:56+00:00
#
#                                       expanded_tweet  \
# 0  Crash on Interstate 295 southbound South of Ex...
# 1  Construction, bridge painting on Atlantic City...
# 2  Roadwork on New Jersey Turnpike inner roadway ...
# 3  Crash on Interstate 76 eastbound at Exit 2 - I...
# 4  Roadwork on New Jersey Turnpike inner roadway ...
#
#                                              highway streets  \
# 0                                     Interstate 295
# 1                           Atlantic City Expressway
# 2  New Jersey Turnpike, Interchange 6 - Pennsylva...
# 3                                      Interstate 76
# 4  New Jersey Turnpike, Interchange 14 - Intersta...
#
#                                                exits  directions locs  \
# 0                                    Exit 29 - US-30  southbound
# 1  Exit 12 - US-40 - Wrangleboro Road, Exit 12 - ...   westbound
# 2                                                     northbound
# 3                            Exit 2 - Interstate 676   eastbound
# 4                                                     Southbound
#
#             lanes                          relocs  \
# 0      right lane                        South of
# 1      right lane        between East of, West of
# 2                                            from
# 3  right shoulder
# 4       all lanes  between North of, and South of
#
#                                    town  \
# 0                        Haddon Heights
# 1  Hamilton Township, Hamilton Township
# 2
# 3                                Camden
# 4                                Newark
#
#                                      location_lookup        lat        lon
# 0                                 Haddon Heights, NJ  39.881870 -75.059300
# 1           Hamilton Township, Hamilton Township, NJ  40.230360 -74.723860
# 2  New Jersey Turnpike, Interchange 6 - Pennsylva...  41.022837 -78.444277
# 3                                         Camden, NJ  39.945250 -75.119130
# 4                                         Newark, NJ  40.731970 -74.174210

# %% [markdown]
# Saving the resulting DataFrame as a csv file for the next notebook to use

# %%
locs_df.to_csv('../datasets/geodata.csv')

# %% [markdown]
# ---
